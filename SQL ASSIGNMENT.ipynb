# %% [markdown]
# Create Tables
# ![create%20tables.png](attachment:create%20tables.png)

# %% [markdown]
# Employeedetails
# ![employeedetails.png](attachment:employeedetails.png)

# %% [markdown]
# Employeesalary table
# ![employeesalary.png](attachment:employeesalary.png)

# %% [markdown]
#  Q1 Fetch records present in one table but not in another table
#     ![Query1.png](attachment:Query1.png)

# %% [markdown]
# Q2 Fetch all employees who are not working on any project.
# ![Query2.png](attachment:Query2.png)

# %% [markdown]
# Q3 Fetch all employees who have joined in year 2020.
# ![query3.png](attachment:query3.png)

# %% [markdown]
# Q4 Fetch all employees from employeedetails who have salary record in employeesalary.
# ![query4.png](attachment:query4.png)

# %% [markdown]
# Q5 Fetch project wise count of employees
# ![Query5.png](attachment:Query5.png)

# %% [markdown]
# Q6 Fetch all employees who are also managers
# ![Qmanager.png](attachment:Qmanager.png)

# %% [markdown]
# Q7 Fetch duplicate records from employeedetails
# ![duplicate.png](attachment:duplicate.png)

# %% [markdown]
# Q8 Fetch only odd rows from table.
# ![odd.png](attachment:odd.png)

# %% [markdown]
# Q9 Find 3rd highest salary without top or limit.
# ![3higsalary.png](attachment:3higsalary.png)
